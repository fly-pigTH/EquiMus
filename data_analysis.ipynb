# %%
# read time_list
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# %%
# 从文件加载 time_list
time_list_loaded = np.load("time_list.npy")
sensor_list_loaded = np.load("sensor_list.npy")

# 检查加载的数据
print("Loaded time_list:", time_list_loaded)
print(sensor_list_loaded.shape)
# sensor_list_loaded[:,1,3]
# plot
plt.plot(time_list_loaded, sensor_list_loaded[:,[0]], label="shoulder joint")
plt.plot(time_list_loaded, sensor_list_loaded[:,[2]], label="kneel joint")
plt.xlabel("time/s")
plt.ylabel("ang/rad")
plt.legend()
# # end point
# end_x = 0.5*np.cos(sensor_list_loaded[:,0])+0.5*np.cos(sensor_list_loaded[:,0])+0.5*np.cos(sensor_list_loaded[:,2]+sensor_list_loaded[:,0])
# end_y = 0.5*np.sin(sensor_list_loaded[:,0])+0.5*np.sin(sensor_list_loaded[:,0])+0.5*np.sin(sensor_list_loaded[:,2]+sensor_list_loaded[:,0])

# plt.plot(end_x, end_y, 'ro')
# Out:
# Loaded time_list: [0.    0.001 0.002 0.003 0.004 0.005 0.006 0.007 0.008 0.009 0.01  0.011
#  0.012 0.013 0.014 0.015 0.016 0.017 0.018 0.019 0.02  0.021 0.022 0.023
#  0.024 0.025 0.026 0.027 0.028 0.029 0.03  0.031 0.032 0.033 0.034 0.035
#  0.036 0.037 0.038 0.039 0.04  0.041 0.042 0.043 0.044 0.045 0.046 0.047
#  0.048 0.049 0.05  0.051 0.052 0.053 0.054 0.055 0.056 0.057 0.058 0.059
#  0.06  0.061 0.062 0.063 0.064 0.065 0.066 0.067 0.068 0.069 0.07  0.071
#  0.072 0.073 0.074 0.075 0.076 0.077 0.078 0.079 0.08  0.081 0.082 0.083
#  0.084 0.085 0.086 0.087 0.088 0.089 0.09  0.091 0.092 0.093 0.094 0.095
#  0.096 0.097 0.098 0.099 0.1   0.101 0.102 0.103 0.104 0.105 0.106 0.107
#  0.108 0.109 0.11  0.111 0.112 0.113 0.114 0.115 0.116 0.117 0.118 0.119
#  0.12  0.121 0.122 0.123 0.124 0.125 0.126 0.127 0.128 0.129 0.13  0.131
#  0.132 0.133 0.134 0.135 0.136 0.137 0.138 0.139 0.14  0.141 0.142 0.143
#  0.144 0.145 0.146 0.147 0.148 0.149 0.15  0.151 0.152 0.153 0.154 0.155
# ...
